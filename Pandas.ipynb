# %% [markdown]
# # Pandas Introduction

# %% [markdown]
# - Pandas is a Python library used for working with data sets.
# - It has functions for analyzing, cleaning, exploring, and manipulating data.
# - Pandas is fast and it has high performance & productivity for users.
# - It is used for data analysis in Python and developed by Wes McKinney in 2008

# %% [markdown]
# # Why we use Pandas

# %% [markdown]
# - Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# - Pandas can clean messy data sets, and make them readable and relevant.
#
# - Relevant data is very important in data science.

# %% [markdown]
# # Installing Pandas

# %% [markdown]
# We have to use following snippet

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# - To use Pandas we have always import it as follows

# %%
import pandas

# %% [markdown]
# - Pandas is usually imported under the pd alias.

# %%
import pandas as pd

# %% [markdown]
# # Pandas Data Structure

# %% [markdown]
# - The Pandas provides two data structures for processing the data
# 1. series
# 2. dataframe

# %% [markdown]
# # 1. Series

# %% [markdown]
# - A Pandas Series is like a column in a table.
#
# - It is a one-dimensional array holding data of any type.

# %% [markdown]
# pandas.Series( data, index, dtype, copy)

# %%
#importing library
import pandas as pd
a = ["Hello", "Good", "Morning"]
# Creating series (column in table)
myvar = pd.Series(a)

print("\nThe series is : \n", myvar)
# Out:
# The series is :
#  0      Hello
# 1       Good
# 2    Morning
# dtype: object

# %% [markdown]
# # Series object attributes

# %% [markdown]
# It includes following attributes
# 1. series.index - Defines the index of the Series.
# 2. series.shape - It returns a tuple of shape of the data.
# 3. series.ndim - It returns the number of dimensions in the data.
# 4. series.dtype - It returns the data type of the data.
# 5. series.size - It returns the size of the data.
# 6. series.empty - It returns True if Series object is empty, otherwise returns false.

# %%
#importing library
import pandas as pd
a = ["Hello", "Good", "Morning"]
# Creating series (column in table)
myvar = pd.Series(a)

print("\nThe series is : \n", myvar)

print("\nIndex of series is : ", myvar.index)

print("\nShape of series is : ", myvar.shape)

print("\nDimension of series is : ", myvar.ndim)

print("\nData type of series is : ", myvar.dtype)

print("\nSize of series is : ", myvar.size)

print("\nIs series empty?  : ", myvar.empty)
# Out:
# The series is :
#  0      Hello
# 1       Good
# 2    Morning
# dtype: object
#
# Index of series is :  RangeIndex(start=0, stop=3, step=1)
#
# Shape of series is :  (3,)
#
# Dimension of series is :  1
#
# Data type of series is :  object
#
# Size of series is :  3
#
# Is series empty?  :  False

# %% [markdown]
# # * Labels (Index)

# %% [markdown]
# - If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.

# %%
#It will return info from index 0
print(myvar[0])

#It will return info from index 1
print(myvar[1])

#It will return info from index 2
print(myvar[2])
# Out:
# Hello
# Good
# Morning

# %% [markdown]
# # * Creating labels (index)

# %%
import pandas as pd

a = [1, 7, 2]
# specifie index name
myvar = pd.Series(a, index = ["x", "y", "z"])

print("\nThe series is : \n", myvar)
# Out:
# The series is :
#  x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# # 2. DataFrames

# %% [markdown]
# - Dataframes is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %% [markdown]
# - pandas.DataFrame( data, index, columns, dtype, copy)

# %% [markdown]
# # * creating dataframes

# %% [markdown]
# - Pandas DataFrame will be created by loading the datasets from existing storage, storage can be SQL Database, CSV file, an Excel file.
# - Pandas DataFrame can be created from the lists, dictionary, and from a list of dictionaries, etc.

# %%
# importing library
import pandas as pd
   
# Creating empty dataframe
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# * Create a DataFrame from Lists

# %%
# importing library
import pandas as pd

# a list of strings  
x = ['Python', 'Pandas', 'Numpy', 'Dataframe', 'Series']  
  
# Creating DataFrame from list  
df = pd.DataFrame(x)  
print("\nDataframe From list is  : \n", df)
# Out:
# Dataframe From list is  :
#             0
# 0     Python
# 1     Pandas
# 2      Numpy
# 3  Dataframe
# 4     Series

# %% [markdown]
# - setting index and column parameter

# %%
# importing library
import pandas as pd

# a list of strings  
x = ['Python', 'Pandas', 'Numpy', 'Dataframe', 'Series']  
  
# Creating DataFrame from list  
df = pd.DataFrame(x, index = ["A", "B", "C", "D", "E"], columns = ['Name'])  
print("\nOur new dataframe is  : \n", df)
# Out:
# Our new dataframe is  :
#          Name
# A     Python
# B     Pandas
# C      Numpy
# D  Dataframe
# E     Series

# %% [markdown]
# * Create a DataFrame from Dict of ndarrays /list

# %%
# importing library
import pandas as pd

#Creating dictionary
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}

df = pd.DataFrame(data)
print("\nDataframe from dictionary is : \n", df)
# Out:
# Dataframe from dictionary is :
#      Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %% [markdown]
# # Locate Row

# %% [markdown]
# - Pandas use the loc attribute to return one or more specified row(s)

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# Name    Tom
# Age      28
# Name: 0, dtype: object

# %%
#use a list of indexes:
#we have to provide specific square bracket also
print(df.loc[[0, 1]])
# Out:
#    Name  Age
# 0   Tom   28
# 1  Jack   34

# %% [markdown]
# # Adding column to dataframes

# %% [markdown]
# - We can also add any new column to an existing DataFrame.

# %%
# importing library
import pandas as pd

#Creating dictionary
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}

df = pd.DataFrame(data)
print("\nDataframe from dictionary is : \n", df)

print("\nAdding new column to existing Dataframe\n")

df['Experience'] = pd.Series([2, 4, 5, 3])
print(df)
# Out:
# Dataframe from dictionary is :
#      Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42
#
# Adding new column to existing Dataframe
#
#     Name  Age  Experience
# 0    Tom   28           2
# 1   Jack   34           4
# 2  Steve   29           5
# 3  Ricky   42           3

# %% [markdown]
# # Deletion of column from dataframes

# %% [markdown]
# - Columns can be deleted or popped

# %% [markdown]
# - Using the previous DataFrame, we will delete a column
# - using del function

# %%
# importing library
import pandas as pd

#Creating dictionary
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42], 'Experience' : [2, 4, 5, 3]}

df = pd.DataFrame(data)
print("\nOur Dataframe  is : \n", df)
# Out:
# Our Dataframe  is :
#      Name  Age  Experience
# 0    Tom   28           2
# 1   Jack   34           4
# 2  Steve   29           5
# 3  Ricky   42           3

# %%
# using del function
print ("Deleting the Second column using DEL function:")
del df['Age']
print(df)
# Out:
# Deleting the first column using DEL function:
#     Name  Experience
# 0    Tom           2
# 1   Jack           4
# 2  Steve           5
# 3  Ricky           3

# %%
# using pop function
print ("Deleting another column using POP function:")
df.pop('Experience')
print(df)
# Out:
# Deleting another column using POP function:
#     Name
# 0    Tom
# 1   Jack
# 2  Steve
# 3  Ricky

# %% [markdown]
# # Addition of rows

# %% [markdown]
# - Add new rows to a DataFrame using the append function.
# - This function will append the rows at the end.

# %%
# importing library
import pandas as pd

#Creating dictionary
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42], 'Experience' : [2, 4, 5, 3]}

df = pd.DataFrame(data)
print("\nOur Dataframe  is : \n", df)

#adding new row
df2 = pd.DataFrame([['Sherlock', 32, 1], ['Watson', 40, 3]], columns = ['Name','Age', 'Experience'])
df = df.append(df2)

print("\nDataframe after new rows addition")
print(df)
# Out:
# Our Dataframe  is :
#      Name  Age  Experience
# 0    Tom   28           2
# 1   Jack   34           4
# 2  Steve   29           5
# 3  Ricky   42           3
#
# Dataframe after new rows addition
#        Name  Age  Experience
# 0       Tom   28           2
# 1      Jack   34           4
# 2     Steve   29           5
# 3     Ricky   42           3
# 0  Sherlock   32           1
# 1    Watson   40           3
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10576\3223807203.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)

# %% [markdown]
# - Using concat method

# %%
# importing library
import pandas as pd

#Creating dictionary
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42], 'Experience' : [2, 4, 5, 3]}

df = pd.DataFrame(data)
print("\nOur Dataframe  is : \n", df)

df2 = pd.DataFrame([['Sherlock', 32, 1], ['Watson', 40, 3]], columns = ['Name','Age', 'Experience'])

#Adding rows using concat method
df3 = pd.concat([df, df2])

print("\nDataframe after new rows addition")
print(df3)
# Out:
# Our Dataframe  is :
#      Name  Age  Experience
# 0    Tom   28           2
# 1   Jack   34           4
# 2  Steve   29           5
# 3  Ricky   42           3
#
# Dataframe after new rows addition
#        Name  Age  Experience
# 0       Tom   28           2
# 1      Jack   34           4
# 2     Steve   29           5
# 3     Ricky   42           3
# 0  Sherlock   32           1
# 1    Watson   40           3

# %% [markdown]
# # Deletion of rows

# %% [markdown]
# - Use index label to delete or drop rows from a DataFrame.
# - If label is duplicated, then multiple rows will be dropped.

# %%
# importing library
import pandas as pd

#Creating dictionary
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42], 'Experience' : [2, 4, 5, 3]}

df = pd.DataFrame(data)
print("\nOur Dataframe  is : \n", df)

#deleting row with index 0 using drop()
df = df.drop(0)

print("\nDataframe after row deletion \n")
df
# Out:
# Our Dataframe  is :
#      Name  Age  Experience
# 0    Tom   28           2
# 1   Jack   34           4
# 2  Steve   29           5
# 3  Ricky   42           3
#
# Dataframe after row deletion
#     Name  Age  Experience
# 1   Jack   34           4
# 2  Steve   29           5
# 3  Ricky   42           3

# %% [markdown]
# # Pandas read CSV

# %% [markdown]
# - csv stands for Comma Separated Values

# %% [markdown]
# - The csv file is opened into the excel file, and the rows and columns data define the standard format.
# - Reading the csv file into a pandas DataFrame is quick and straight forward.

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\student1.csv")

# %%
df
# Out:
#        name  gmat  gpa  exp  admitted country
# 0     samir   780  4.0    3         1     Ind
# 1   kaushal   750  3.9    4         1     Ind
# 2    nandan   690  3.3    3         0     Ind
# 3     ankit   710  3.7    5         1      us
# 4   deepika   680  3.9    4         0     Ind
# 5    kshama   730  3.7    6         1     Ind
# 6    gaurav   690  2.3    1         0      us
# 7      john   720  3.3    4         1      us
# 8      nida   740  3.3    5         1     Ind
# 9     samir   690  1.7    1         0     Ind
# 10  kaushal   610  2.7    3         0     Ind
# 11   nandan   690  3.7    5         1     Ind
# 12    ankit   710  3.7    6         1      us
# 13  deepika   680  3.3    4         0     Ind
# 14   kshama   770  3.3    3         1     Ind
# 15   gaurav   510  3.0    1         0     Ind
# 16     john   580  2.7    4         0     Ind
# 17     nida   650  3.7    6         1     Ind
# 18    samir   540  2.7   24         0     Ind
# 19  kaushal   590  2.3    3         0     Ind
# 20   nandan   620  3.3    2         1      us
# 21    ankit   600  2.0    1         0     Ind
# 22  deepika   550  2.3    4         0     Ind
# 23   kshama   550  2.7    1         0     Ind
# 24   gaurav   570  3.0    2         0      us
# 25     john   670  3.3    6         1     Ind
# 26     nida   660  3.7    4         1     Ind
# 27    samir   580  2.3    2         0     Ind
# 28  kaushal   650  3.7    6         1     Ind
# 29   nandan   660  3.3    5         1      us
# 30    ankit   640  3.0    1         0     Ind
# 31  deepika   620  2.7    2         0     Ind
# 32   kshama   660  4.0    4         1     Ind
# 33   gaurav   660  3.3    6         1     Ind
# 34     john   680  3.3    5         1     Ind
# 35     nida   650  2.3    1         0     Ind
# 36    samir   670  2.7    2         0      us
# 37  kaushal   580  3.3    1         0     Ind
# 38   nandan   590  1.7    4         0     Ind
# 39    ankit   690  3.7    5         1      us
# 40  deepika   690  3.7    5         1     Ind
# 41   kshama   690  3.7    5         1     Ind

# %% [markdown]
# # Basic Functionality on Dataframe

# %% [markdown]
# It includes following attribute / method
# 1. dtype
# 2. ndim
# 3. size
# 4. head
# 5. tail
# 6. info
# 7. axes
# 8. empty
# 9. shape
# 10. sample
# 11. T (Transpose)

# %% [markdown]
# short snippet for all above methods

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\student1.csv")
print("\nOur dataframe is : \n", df)

# To check the type of our dataframe
print("\nType of our dataframe is : " , type(df))


# To check the dimension of our dataframe
print("\nDimension of our dataframe is : " , df.ndim)

# To check the size of our dataframe
print("\nSize of our dataframe is : " , df.size)

# Return first 5 sample of dataframe
print("\nFirst 5 entries from our dataframe is : \n" , df.head())

# Return last 5 sample dataframe
print("\nLast 5 entries from our dataframe is : \n" , df.tail())

print("\n")

#Return all information about dataframe
print(df.info())

#Returns the list of the labels of the series.
print("\nLabel of our dataframe is : \n", df.axes)

#Returns the Boolean value saying whether the Object is empty or not. 
#True indicates that the object is empty.
print("\nGiven dataframe contain empty series or not : \n", df.empty)

# To check the shape of our dataframe
print("\nShape of our dataframe is : " , df.shape)

# Return random sample from dataframe
print("\nRandom entries from our dataframe is : \n" , df.sample())
# Out:
# Our dataframe is :
#         name  gmat  gpa  exp  admitted country
# 0     samir   780  4.0    3         1     Ind
# 1   kaushal   750  3.9    4         1     Ind
# 2    nandan   690  3.3    3         0     Ind
# 3     ankit   710  3.7    5         1      us
# 4   deepika   680  3.9    4         0     Ind
# 5    kshama   730  3.7    6         1     Ind
# 6    gaurav   690  2.3    1         0      us
# 7      john   720  3.3    4         1      us
# 8      nida   740  3.3    5         1     Ind
# 9     samir   690  1.7    1         0     Ind
# 10  kaushal   610  2.7    3         0     Ind
# 11   nandan   690  3.7    5         1     Ind
# 12    ankit   710  3.7    6         1      us
# 13  deepika   680  3.3    4         0     Ind
# 14   kshama   770  3.3    3         1     Ind
# 15   gaurav   510  3.0    1         0     Ind
# 16     john   580  2.7    4         0     Ind
# 17     nida   650  3.7    6         1     Ind
# 18    samir   540  2.7   24         0     Ind
# 19  kaushal   590  2.3    3         0     Ind
# 20   nandan   620  3.3    2         1      us
# 21    ankit   600  2.0    1         0     Ind
# 22  deepika   550  2.3    4         0     Ind
# 23   kshama   550  2.7    1         0     Ind
# 24   gaurav   570  3.0    2         0      us
# 25     john   670  3.3    6         1     Ind
# 26     nida   660  3.7    4         1     Ind
# 27    samir   580  2.3    2         0     Ind
# 28  kaushal   650  3.7    6         1     Ind
# 29   nandan   660  3.3    5         1      us
# 30    ankit   640  3.0    1         0     Ind
# 31  deepika   620  2.7    2         0     Ind
# 32   kshama   660  4.0    4         1     Ind
# 33   gaurav   660  3.3    6         1     Ind
# 34     john   680  3.3    5         1     Ind
# 35     nida   650  2.3    1         0     Ind
# 36    samir   670  2.7    2         0      us
# 37  kaushal   580  3.3    1         0     Ind
# 38   nandan   590  1.7    4         0     Ind
# 39    ankit   690  3.7    5         1      us
# 40  deepika   690  3.7    5         1     Ind
# 41   kshama   690  3.7    5         1     Ind
#
# Type of our dataframe is :  <class 'pandas.core.frame.DataFrame'>
#
# Dimension of our dataframe is :  2
#
# Size of our dataframe is :  252
#
# First 5 entries from our dataframe is :
#        name  gmat  gpa  exp  admitted country
# 0    samir   780  4.0    3         1     Ind
# 1  kaushal   750  3.9    4         1     Ind
# 2   nandan   690  3.3    3         0     Ind
# 3    ankit   710  3.7    5         1      us
# 4  deepika   680  3.9    4         0     Ind
#
# Last 5 entries from our dataframe is :
#         name  gmat  gpa  exp  admitted country
# 37  kaushal   580  3.3    1         0     Ind
# 38   nandan   590  1.7    4         0     Ind
# 39    ankit   690  3.7    5         1      us
# 40  deepika   690  3.7    5         1     Ind
# 41   kshama   690  3.7    5         1     Ind
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      42 non-null     object
#  1   gmat      42 non-null     int64
#  2   gpa       42 non-null     float64
#  3   exp       42 non-null     int64
#  4   admitted  42 non-null     int64
#  5   country   42 non-null     object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.1+ KB
# None
#
# Label of our dataframe is :
#  [RangeIndex(start=0, stop=42, step=1), Index(['name', 'gmat', 'gpa', 'exp', 'admitted', 'country'], dtype='object')]
#
# Given dataframe contain empty series or not :
#  False
#
# Shape of our dataframe is :  (42, 6)
#
# Random entries from our dataframe is :
#     name  gmat  gpa  exp  admitted country
# 8  nida   740  3.3    5         1     Ind

# %%
#Returns the transpose of the DataFrame. The rows and columns will interchange.
print("\nTranspose of dataframe is : \n")
df.T
# Out:
# Transpose of dataframe is :
#              0        1       2      3        4       5       6     7     8   \
# name      samir  kaushal  nandan  ankit  deepika  kshama  gaurav  john  nida
# gmat        780      750     690    710      680     730     690   720   740
# gpa         4.0      3.9     3.3    3.7      3.9     3.7     2.3   3.3   3.3
# exp           3        4       3      5        4       6       1     4     5
# admitted      1        1       0      1        0       1       0     1     1
# country     Ind      Ind     Ind     us      Ind     Ind      us    us   Ind
#
#              9   ...      32      33    34    35     36       37      38  \
# name      samir  ...  kshama  gaurav  john  nida  samir  kaushal  nandan
# gmat        690  ...     660     660   680   650    670      580     590
# gpa         1.7  ...     4.0     3.3   3.3   2.3    2.7      3.3     1.7
# exp           1  ...       4       6     5     1      2        1       4
# admitted      0  ...       1       1     1     0      0        0       0
# country     Ind  ...     Ind     Ind   Ind   Ind     us      Ind     Ind
#
#              39       40      41
# name      ankit  deepika  kshama
# gmat        690      690     690
# gpa         3.7      3.7     3.7
# exp           5        5       5
# admitted      1        1       1
# country      us      Ind     Ind
#
# [6 rows x 42 columns]

# %% [markdown]
# # * Summarizing Data

# %% [markdown]
# - The describe() function computes a summary of statistics pertaining to the DataFrame columns.

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\student1.csv")

print("\nSummary of our Columns is: \n")
df.describe()
# Out:
# Summary of our Columns is:
#              gmat        gpa        exp   admitted
# count   42.000000  42.000000  42.000000  42.000000
# mean   653.333333   3.123810   4.023810   0.500000
# std     64.113720   0.629289   3.591916   0.506061
# min    510.000000   1.700000   1.000000   0.000000
# 25%    602.500000   2.700000   2.000000   0.000000
# 50%    660.000000   3.300000   4.000000   0.500000
# 75%    690.000000   3.700000   5.000000   1.000000
# max    780.000000   4.000000  24.000000   1.000000

# %% [markdown]
# - We can also specifies to Summarizes String columns

# %%
print("\nSummary of our Columns is: \n") 
df.describe(include=['object'])
# Out:
# Summary of our Columns is:
#                 Date
# count             31
# unique            30
# top     '2020/12/12'
# freq               2

# %% [markdown]
# - We can also specifies to Summarizes Numeric columns

# %%
print("\nSummary of our Columns is: \n")
df.describe(include=['number'])
# Out:
# Summary of our Columns is:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   31.000000   32.000000   30.000000
# mean    68.437500  103.419355  128.500000  304.680000
# std     70.039591    7.948896   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.000000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %% [markdown]
# # Pandas Cleaning Data

# %% [markdown]
# It consists of
# 1. Empty cells
# 2. remove empty rows
# 3. Replace empty values
# 4. Replace only for specified column
# 5. Replace Using Mean, Median, or Mode
# 6. Data of Wrong Format
# 7. Fixing Wrong Data
# 8. Discovering Duplicates
# 9. Removing Duplicates

# %% [markdown]
# # 1. Empty cells

# %% [markdown]
# - Empty cells can potentially give you a wrong result when you analyze data.

# %% [markdown]
# -Checking for null values

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")
 
#return True where value is not present
df.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False   True     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# 19     False  False  False     False     False
# 20     False  False  False     False     False
# 21     False  False  False     False     False
# 22     False   True  False     False     False
# 23     False  False  False     False     False
# 24     False  False  False     False     False
# 25     False  False  False     False     False
# 26     False  False  False     False     False
# 27     False  False  False     False     False
# 28     False  False  False     False      True
# 29     False  False  False     False     False
# 30     False  False  False     False     False
# 31     False  False  False     False     False

# %% [markdown]
# - Return count of total null values

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")
 
#return True where value is not present
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       1
# Maxpulse    0
# Calories    2
# dtype: int64

# %% [markdown]
# # 2. Remove empty rows

# %% [markdown]
# - By default, the dropna() method returns a new DataFrame, and will not change the original.

# %% [markdown]
# - It remove row 13, 22 and 28

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")
 
new_df = df.dropna()

new_df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# - If you want to change the original DataFrame, use the inplace = True argument:

# %% [markdown]
# -  Now, the dropna(inplace = True) will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")
 
df.dropna(inplace = True)

df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # 3. Replace empty values

# %% [markdown]
# - Another way of dealing with empty cells is to insert a new value instead.
#
# - This way you do not have to delete entire rows just because of some empty cells.
#
# - The fillna() method allows us to replace empty cells with a value:

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#fill empty cell with value
df.fillna(140, inplace = True)

df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'  140.0       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112     140.0
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           140  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132     140.0
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # 4. Replace only for specified column

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#fill specified empty cell with value
df["Pulse"].fillna(130, inplace = True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'  130.0       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # 5. Replace Using Mean, Median, or Mode

# %% [markdown]
# - A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# - Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column:

# %% [markdown]
# - It update 13th row

# %% [markdown]
# - Mean = the average value (the sum of all values divided by number of values).

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#Calculating mean of pulse column
x = df["Pulse"].mean()

print("Mean of Pulse is : ", x)

#fill specified empty cell with mean value
df["Pulse"].fillna(x, inplace = True)

df
# Out:
# Mean of Pulse is :  103.41935483870968
#     Duration          Date       Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.000000       130     409.1
# 1         60  '2020/12/02'  117.000000       145     479.0
# 2         60  '2020/12/03'  103.000000       135     340.0
# 3         45  '2020/12/04'  109.000000       175     282.4
# 4         45  '2020/12/05'  117.000000       148     406.0
# 5         60  '2020/12/06'  102.000000       127     300.0
# 6         60  '2020/12/07'  110.000000       136     374.0
# 7        450  '2020/12/08'  104.000000       134     253.3
# 8         30  '2020/12/09'  109.000000       133     195.1
# 9         60  '2020/12/10'   98.000000       124     269.0
# 10        60  '2020/12/11'  103.000000       147     329.3
# 11        60  '2020/12/12'  100.000000       120     250.7
# 12        60  '2020/12/12'  100.000000       120     250.7
# 13        60  '2020/12/13'  103.419355       128     345.3
# 14        60  '2020/12/14'  104.000000       132     379.3
# 15        60  '2020/12/15'   98.000000       123     275.0
# 16        60  '2020/12/16'   98.000000       120     215.2
# 17        60  '2020/12/17'  100.000000       120     300.0
# 18        45  '2020/12/18'   90.000000       112       NaN
# 19        60  '2020/12/19'  103.000000       123     323.0
# 20        45  '2020/12/20'   97.000000       125     243.0
# 21        60  '2020/12/21'  108.000000       131     364.2
# 22        45           NaN  100.000000       119     282.0
# 23        60  '2020/12/23'  130.000000       101     300.0
# 24        45  '2020/12/24'  105.000000       132     246.0
# 25        60  '2020/12/25'  102.000000       126     334.5
# 26        60      20201226  100.000000       120     250.0
# 27        60  '2020/12/27'   92.000000       118     241.0
# 28        60  '2020/12/28'  103.000000       132       NaN
# 29        60  '2020/12/29'  100.000000       132     280.0
# 30        60  '2020/12/30'  102.000000       129     380.3
# 31        60  '2020/12/31'   92.000000       115     243.0

# %% [markdown]
# - Replacing using median()

# %% [markdown]
#  - Median = the value in the middle, after you have sorted all values ascending.

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#Calculating mean of pulse column
x = df["Pulse"].median()

print("Median of Pulse is : ", x)

#fill specified empty cell with median value
df["Pulse"].fillna(x, inplace = True)

df
# Out:
# Median of Pulse is :  102.0
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'  102.0       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# - Replacing using mode()

# %% [markdown]
# - Mode = the value that appears most frequently.

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#Calculating mean of pulse column
x = df["Pulse"].mode()[0]

print("Mode of Pulse is : ", x)

#fill specified empty cell with mode value
df["Pulse"].fillna(x, inplace = True)

df
# Out:
# Mode of Pulse is :  100.0
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'  100.0       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # 6. Data of Wrong Format

# %% [markdown]
# - Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
#
# - To fix it, you have two options:
#    1. remove the rows
#    2. convert all cells in the columns into the same format.

# %% [markdown]
# # 1. remove the rows

# %% [markdown]
# - The result from the converting in the example above gave us a NaT value, which can be handled as a NULL value, and we can remove the row by using the dropna() method.

# %% [markdown]
# - It removes 22th row

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

df.dropna(subset=['Date'], inplace = True)

df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # 2. Convert Into a Correct Format

# %% [markdown]
# - In our Data Frame, we have two cells with the wrong format. Check out row 22 and 26, the 'Date' column should be a string that represents a date:

# %% [markdown]
# - Let's try to convert all cells in the 'Date' column into dates.
#
# - Pandas has a to_datetime() method for this:

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

df['Date'] = pd.to_datetime(df['Date'])

df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01  110.0       130     409.1
# 1         60 2020-12-02  117.0       145     479.0
# 2         60 2020-12-03  103.0       135     340.0
# 3         45 2020-12-04  109.0       175     282.4
# 4         45 2020-12-05  117.0       148     406.0
# 5         60 2020-12-06  102.0       127     300.0
# 6         60 2020-12-07  110.0       136     374.0
# 7        450 2020-12-08  104.0       134     253.3
# 8         30 2020-12-09  109.0       133     195.1
# 9         60 2020-12-10   98.0       124     269.0
# 10        60 2020-12-11  103.0       147     329.3
# 11        60 2020-12-12  100.0       120     250.7
# 12        60 2020-12-12  100.0       120     250.7
# 13        60 2020-12-13    NaN       128     345.3
# 14        60 2020-12-14  104.0       132     379.3
# 15        60 2020-12-15   98.0       123     275.0
# 16        60 2020-12-16   98.0       120     215.2
# 17        60 2020-12-17  100.0       120     300.0
# 18        45 2020-12-18   90.0       112       NaN
# 19        60 2020-12-19  103.0       123     323.0
# 20        45 2020-12-20   97.0       125     243.0
# 21        60 2020-12-21  108.0       131     364.2
# 22        45        NaT  100.0       119     282.0
# 23        60 2020-12-23  130.0       101     300.0
# 24        45 2020-12-24  105.0       132     246.0
# 25        60 2020-12-25  102.0       126     334.5
# 26        60 2020-12-26  100.0       120     250.0
# 27        60 2020-12-27   92.0       118     241.0
# 28        60 2020-12-28  103.0       132       NaN
# 29        60 2020-12-29  100.0       132     280.0
# 30        60 2020-12-30  102.0       129     380.3
# 31        60 2020-12-31   92.0       115     243.0

# %% [markdown]
# # 7. Fixing Wrong Data

# %% [markdown]
# - If you take a look at our data set, you can see that in row 7, the duration is 450, but for all the other rows the duration is between 30 and 60.

# %% [markdown]
# - It includes two method to fix wrong data
# 1. Replacing Values
# 2. Removing Rows

# %% [markdown]
# # 1. Replacing Values

# %% [markdown]
# - In our example, it is most likely a typo, and the value should be "45" instead of "450", and we could just insert "45" in row 7:

# %%
#importing module
import pandas as pd

#Reading data from csv

df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

df.loc[7, 'Duration'] = 45

df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7         45  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# - To replace wrong data for larger data sets you can create some rules, e.g. set some boundaries for legal values, and replace any values that are outside of the boundaries.

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#Applying condition if there is large amount of data
for x in df.index:
    if df.loc[x, "Duration"] > 60:
        df.loc[x, "Duration"] = 60
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7         60  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # 2. Removing Rows

# %% [markdown]
# - Another way of handling wrong data is to remove the rows that contains wrong data.

# %% [markdown]
# - It remove 7th location

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#Applying condition if there is large amount of data
for x in df.index:
    if df.loc[x, "Duration"] > 60:
        df.drop(x, inplace = True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # 8. Discovering Duplicates

# %% [markdown]
# - Duplicate rows are rows that have been registered more than one time.

# %% [markdown]
# - To discover duplicates, we can use the duplicated() method.
#
# - The duplicated() method returns a Boolean values for each row:

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %% [markdown]
# # 9. Removing Duplicates

# %% [markdown]
# - To remove duplicates, use the drop_duplicates() method.

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#removing duplicate entries from data
df.drop_duplicates(inplace = True)

df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # * Accessing data using location

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#It return data from 3rd index
df.loc[3]
# Out:
# Duration              45
# Date        '2020/12/04'
# Pulse              109.0
# Maxpulse             175
# Calories           282.4
# Name: 3, dtype: object

# %% [markdown]
# - we can perform slicing on it also

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#It return data from 3rd index
df.loc[1:5]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 1        60  '2020/12/02'  117.0       145     479.0
# 2        60  '2020/12/03'  103.0       135     340.0
# 3        45  '2020/12/04'  109.0       175     282.4
# 4        45  '2020/12/05'  117.0       148     406.0
# 5        60  '2020/12/06'  102.0       127     300.0

# %% [markdown]
# # * replace() method

# %% [markdown]
# - If we want replace any value
# - if we want replace all value with specified column
# then replace() method is used

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#replace every 60 with 120
df.replace(60, 120)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        45  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        45  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        45           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        45  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# - replacing with particular column name

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

#replace every 60 with 120
df['Duration'].replace(45, 60, inplace = True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         60  '2020/12/04'  109.0       175     282.4
# 4         60  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# 17        60  '2020/12/17'  100.0       120     300.0
# 18        60  '2020/12/18'   90.0       112       NaN
# 19        60  '2020/12/19'  103.0       123     323.0
# 20        60  '2020/12/20'   97.0       125     243.0
# 21        60  '2020/12/21'  108.0       131     364.2
# 22        60           NaN  100.0       119     282.0
# 23        60  '2020/12/23'  130.0       101     300.0
# 24        60  '2020/12/24'  105.0       132     246.0
# 25        60  '2020/12/25'  102.0       126     334.5
# 26        60      20201226  100.0       120     250.0
# 27        60  '2020/12/27'   92.0       118     241.0
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %% [markdown]
# # * Converting Dataframe to numpy array

# %% [markdown]
# - But here we lost our column name

# %%
#importing module
import pandas as pd

#Reading data from csv
df = pd.read_csv("F:\\PGD_Data_Science\\Lecture_video\\panda\\dirtydata.csv")

array = df.to_numpy()
array
# Out:
# array([[60, "'2020/12/01'", 110.0, 130, 409.1],
#        [60, "'2020/12/02'", 117.0, 145, 479.0],
#        [60, "'2020/12/03'", 103.0, 135, 340.0],
#        [45, "'2020/12/04'", 109.0, 175, 282.4],
#        [45, "'2020/12/05'", 117.0, 148, 406.0],
#        [60, "'2020/12/06'", 102.0, 127, 300.0],
#        [60, "'2020/12/07'", 110.0, 136, 374.0],
#        [450, "'2020/12/08'", 104.0, 134, 253.3],
#        [30, "'2020/12/09'", 109.0, 133, 195.1],
#        [60, "'2020/12/10'", 98.0, 124, 269.0],
#        [60, "'2020/12/11'", 103.0, 147, 329.3],
#        [60, "'2020/12/12'", 100.0, 120, 250.7],
#        [60, "'2020/12/12'", 100.0, 120, 250.7],
#        [60, "'2020/12/13'", nan, 128, 345.3],
#        [60, "'2020/12/14'", 104.0, 132, 379.3],
#        [60, "'2020/12/15'", 98.0, 123, 275.0],
#        [60, "'2020/12/16'", 98.0, 120, 215.2],
#        [60, "'2020/12/17'", 100.0, 120, 300.0],
#        [45, "'2020/12/18'", 90.0, 112, nan],
#        [60, "'2020/12/19'", 103.0, 123, 323.0],
#        [45, "'2020/12/20'", 97.0, 125, 243.0],
#        [60, "'2020/12/21'", 108.0, 131, 364.2],
#        [45, nan, 100.0, 119, 282.0],
#        [60, "'2020/12/23'", 130.0, 101, 300.0],
#        [45, "'2020/12/24'", 105.0, 132, 246.0],
#        [60, "'2020/12/25'", 102.0, 126, 334.5],
#        [60, '20201226', 100.0, 120, 250.0],
#        [60, "'2020/12/27'", 92.0, 118, 241.0],
#        [60, "'2020/12/28'", 103.0, 132, nan],
#        [60, "'2020/12/29'", 100.0, 132, 280.0],
#        [60, "'2020/12/30'", 102.0, 129, 380.3],
#        [60, "'2020/12/31'", 92.0, 115, 243.0]], dtype=object)

# %% [markdown]
# #- We perform operation vice versa

# %%
df = pd.DataFrame(array)
df
# Out:
#       0             1      2    3      4
# 0    60  '2020/12/01'  110.0  130  409.1
# 1    60  '2020/12/02'  117.0  145  479.0
# 2    60  '2020/12/03'  103.0  135  340.0
# 3    45  '2020/12/04'  109.0  175  282.4
# 4    45  '2020/12/05'  117.0  148  406.0
# 5    60  '2020/12/06'  102.0  127  300.0
# 6    60  '2020/12/07'  110.0  136  374.0
# 7   450  '2020/12/08'  104.0  134  253.3
# 8    30  '2020/12/09'  109.0  133  195.1
# 9    60  '2020/12/10'   98.0  124  269.0
# 10   60  '2020/12/11'  103.0  147  329.3
# 11   60  '2020/12/12'  100.0  120  250.7
# 12   60  '2020/12/12'  100.0  120  250.7
# 13   60  '2020/12/13'    NaN  128  345.3
# 14   60  '2020/12/14'  104.0  132  379.3
# 15   60  '2020/12/15'   98.0  123  275.0
# 16   60  '2020/12/16'   98.0  120  215.2
# 17   60  '2020/12/17'  100.0  120  300.0
# 18   45  '2020/12/18'   90.0  112    NaN
# 19   60  '2020/12/19'  103.0  123  323.0
# 20   45  '2020/12/20'   97.0  125  243.0
# 21   60  '2020/12/21'  108.0  131  364.2
# 22   45           NaN  100.0  119  282.0
# 23   60  '2020/12/23'  130.0  101  300.0
# 24   45  '2020/12/24'  105.0  132  246.0
# 25   60  '2020/12/25'  102.0  126  334.5
# 26   60      20201226  100.0  120  250.0
# 27   60  '2020/12/27'   92.0  118  241.0
# 28   60  '2020/12/28'  103.0  132    NaN
# 29   60  '2020/12/29'  100.0  132  280.0
# 30   60  '2020/12/30'  102.0  129  380.3
# 31   60  '2020/12/31'   92.0  115  243.0

# %% [markdown]
# - We have to set column name for above data

# %%
df = pd.DataFrame(array, columns = ['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'])
df
# Out:
#    Duration          Date  Pulse Maxpulse Calories
# 0        60  '2020/12/01'  110.0      130    409.1
# 1        60  '2020/12/02'  117.0      145    479.0
# 2        60  '2020/12/03'  103.0      135    340.0
# 3        45  '2020/12/04'  109.0      175    282.4
# 4        45  '2020/12/05'  117.0      148    406.0
# 5        60  '2020/12/06'  102.0      127    300.0
# 6        60  '2020/12/07'  110.0      136    374.0
# 7       450  '2020/12/08'  104.0      134    253.3
# 8        30  '2020/12/09'  109.0      133    195.1
# 9        60  '2020/12/10'   98.0      124    269.0
# 10       60  '2020/12/11'  103.0      147    329.3
# 11       60  '2020/12/12'  100.0      120    250.7
# 12       60  '2020/12/12'  100.0      120    250.7
# 13       60  '2020/12/13'    NaN      128    345.3
# 14       60  '2020/12/14'  104.0      132    379.3
# 15       60  '2020/12/15'   98.0      123    275.0
# 16       60  '2020/12/16'   98.0      120    215.2
# 17       60  '2020/12/17'  100.0      120    300.0
# 18       45  '2020/12/18'   90.0      112      NaN
# 19       60  '2020/12/19'  103.0      123    323.0
# 20       45  '2020/12/20'   97.0      125    243.0
# 21       60  '2020/12/21'  108.0      131    364.2
# 22       45           NaN  100.0      119    282.0
# 23       60  '2020/12/23'  130.0      101    300.0
# 24       45  '2020/12/24'  105.0      132    246.0
# 25       60  '2020/12/25'  102.0      126    334.5
# 26       60      20201226  100.0      120    250.0
# 27       60  '2020/12/27'   92.0      118    241.0
# 28       60  '2020/12/28'  103.0      132      NaN
# 29       60  '2020/12/29'  100.0      132    280.0
# 30       60  '2020/12/30'  102.0      129    380.3
# 31       60  '2020/12/31'   92.0      115    243.0
